# %%
import pandas as pd
import numpy as np
import scipy
import os
import json
import nltk

# %%
import gensim

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\haghigy\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
###begining of the test

# %%
import openfoodfacts

# %%
ingredients = openfoodfacts.facets.get_ingredients()

# %%
ingredients
# Out:
# [{'origins_debug_tags': [],
#   'countries_lc': 'fr',
#   'interface_version_created': '20120622',
#   'nutrient_levels': {'fat': 'moderate',
#    'sugars': 'high',
#    'salt': 'low',
#    'saturated-fat': 'high'},
#   'purchase_places_tags': ['quincy-sous-senart', 'france'],
#   'stores': 'Lidl',
#   'product_name_fr': 'Tiramisu',
#   'states_hierarchy': ['en:to-be-checked',
#    'en:complete',
#    'en:nutrition-facts-completed',
#    'en:ingredients-completed',
#    'en:expiration-date-completed',
#    'en:packaging-code-completed',
#    'en:characteristics-completed',
#    'en:categories-completed',
#    'en:brands-completed',
#    'en:packaging-completed',
#    'en:quantity-completed',
#    'en:product-name-completed',
#    'en:photos-validated',
#    'en:photos-uploaded'],
#   'manufacturing_places_tags': ['dolcissimo-srl-via-fratelli-cervi-41-20010-ossona',
#    'mi-milan',
#    'lombardie',
#    'italie'],
#   'nutrition_grades_tags': ['d'],
#   'brands_debug_tags': [],
# ...

# %%
### end of test

# %%
from gensim import corpora
from pprint import pprint

# %%
path = os.getcwd() 
files = os.listdir(path)
files_xls = [f for f in files if f[-4:] == 'xlsx']
files_xls
# Out:
# ['baking.xlsx',
#  'baking_mixes.xlsx',
#  'beans.xlsx',
#  'beef.xlsx',
#  'breading.xlsx',
#  'butter.xlsx',
#  'canned_fish.xlsx',
#  'canned_fruits.xlsx',
#  'canned_meat.xlsx',
#  'canned_milk.xlsx',
#  'canned_pasta.xlsx',
#  'canned_stew.xlsx',
#  'canned_vegetables.xlsx',
#  'chicken_turkey.xlsx',
#  'chocolate.xlsx',
#  'dairy.xlsx',
#  'dough.xlsx',
#  'eggs.xlsx',
#  'extracts.xlsx',
#  'filling.xlsx',
#  'frozen_vegetables.xlsx',
#  'fruits.xlsx',
#  'gravy.xlsx',
#  'icing.xlsx',
#  'meal_solutions.xlsx',
#  'noodles.xlsx',
#  'pasta.xlsx',
#  'pasta_sauce.xlsx',
#  'pork.xlsx',
#  'pudding.xlsx',
#  'rice.xlsx',
#  'salad.xlsx',
#  'salt.xlsx',
#  'sauce.xlsx',
#  'seafood.xlsx',
#  'seasoning.xlsx',
#  'side_dishes.xlsx',
#  'sour_cream.xlsx',
#  'spices.xlsx',
#  'tomato_paste.xlsx',
#  'vegetables.xlsx',
#  'yogurt.xlsx']

# %%
items=pd.DataFrame()

# %%
for f in files_xls:
    data=pd.read_excel(f, sheet_name='Sheet1', header=0)
    items=items.append(data, sort=False)

# %%
items.columns=['Item','Measurement','Price','Category']

# %%
items['tokenized']=""

# %%
items.head()
# Out:
#                                      Item Measurement  Price Category  \
# 0            Great Value Pure Baking Soda       454 g   0.98   baking
# 1           ARM & HAMMER Pure Baking Soda       500 g   1.28   baking
# 2  Great Value Original All-Purpose Flour      2.5 kg   3.58   baking
# 3                 Great Value Corn Starch       500 g   2.27   baking
# 4     Fleischmann's Traditional Yeast Jar       113 g   3.87   baking
#
#   tokenized
# 0
# 1
# 2
# 3
# 4

# %%
items.shape
# Out:
# (2385, 5)

# %%
items.iloc[0,0]
# Out:
# 'Great Value Pure Baking Soda'

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\haghigy\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\kernel\__init__.py:13: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   "You should import from ipykernel or jupyter_client instead.", ShimWarning)
# WARNING: AstropyDeprecationWarning: astropy.utils.compat.futures is now deprecated - use concurrent.futures instead [astropy.utils.compat.futures]
# C:\Users\haghigy\AppData\Local\Continuum\anaconda3\lib\site-packages\odo\backends\pandas.py:102: FutureWarning: pandas.tslib is deprecated and will be removed in a future version.
# You can access NaTType as type(pandas.NaT)
#   @convert.register((pd.Timestamp, pd.Timedelta), (pd.tslib.NaTType, type(None)))
# ...

# %%
from nltk.tokenize import word_tokenize
for item in items.Item:
    print(word_tokenize(item))
# Out:
# ['Great', 'Value', 'Pure', 'Baking', 'Soda']
# ['ARM', '&', 'HAMMER', 'Pure', 'Baking', 'Soda']
# ['Great', 'Value', 'Original', 'All-Purpose', 'Flour']
# ['Great', 'Value', 'Corn', 'Starch']
# ['Fleischmann', "'s", 'Traditional', 'Yeast', 'Jar']
# ['Great', 'Value', 'Original', 'Marshmallows']
# ['ARM', '&', 'HAMMER', 'Pure', 'Baking', 'Soda']
# ['Robin', 'Hood', 'Original', 'All', 'Purpose', 'Flour', '10kg']
# ['Magic', 'Baking', 'Powder']
# ['BAKING', 'POWDER']
# ['Five', 'Roses', 'White', 'All', 'Purpose', 'Flour', '10kg']
# ['Robin', 'Hood', 'Original', 'All', 'Purpose', 'Flour', '2.5kg']
# ['Our', 'Finest', '100', '%', 'Virgin', 'Coconut', 'Oil']
# ['Great', 'Value', 'Graham', 'Baking', 'Crumbs']
# ['Flesichmann', "'s", 'Canada', 'Corn', 'Starch']
# ['Fleischmann', "'s", 'Quick', 'Rise']
# ['Robin', 'Hood', 'Gluten', 'Free', 'All', 'Purpose', 'Flour', 'Blend', '907g']
# ['Great', 'Value', 'Original', 'All-Purpose', 'Flour']
# ...

# %%
### Fuzzy Teseting

# %%
import fuzzywuzzy

# %%
from fuzzywuzzy import fuzz
# Out:
# C:\Users\haghigy\AppData\Local\Continuum\anaconda3\lib\site-packages\fuzzywuzzy-0.10.0-py2.7.egg\fuzzywuzzy\fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning

# %%
fuzz.token_set_ratio('bell pepper', 'red bell pepper')
# Out:
# 100

# %%
library=pd.read_json("library")

# %%
library[29]['ingredients']
# Out:
# ['pork butt',
#  'Sriracha',
#  'ketchup',
#  'lime juice',
#  'dried parsley',
#  'honey',
#  'ground black pepper',
#  'salt',
#  'olive oil']

# %%
for recipe in library:
    for ingredient in library[recipe]['ingredients']:
        print('ingredient is', ingredient)
        for item in items.Thing:
            match= fuzz.token_sort_ratio(ingredient, item)
            if match>60:
                print ("matched with:", item, match)
# Out:
# ingredient is cherry tomatoes
# matched with: Tomato, Roma 62
# matched with: Tomato, Cherry 93
# matched with: Aylmer® Crushed Tomatoes 63
# matched with: Aylmer® Diced Tomatoes 61
# matched with: AYLMER® Plum Tomatoes 63
# matched with: Aylmer® Whole Tomatoes 61
# matched with: Tomato, Roma 62
# matched with: Tomato, Cherry 93
# matched with: Tomato Medley 64
# matched with: Duo Tomatoes 67
# ingredient is olive oil
# ingredient is garlic
# matched with: SPAM garlic 71
# matched with: Minced Garlic 63
# matched with: Garlic 100
# matched with: Garlic, Peeled 63
# matched with: Garlic 100
# ingredient is salt
# ingredient is pepper
# ingredient is penne
# ingredient is fresh mozzarella
# ingredient is fresh basil
# matched with: Basil 62
# ingredient is tomatoes
# matched with: Tomato, Roma 63
# matched with: Tomato, Roma 63
# matched with: Duo Tomatoes 80
# matched with: Tomato, Zima 63
# ingredient is carrot
# matched with: Carrots, Baby 67
# matched with: Carrots, Mini 67
# ...

# %%
import spacy

# %%
import en_core_web_sm

# %%
nlp = spacy.load('C:/Users/haghigy/AppData/Local/Continuum/anaconda3/lib/site-packages/spacy/en_core_web_sm-2.1.0')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-68-dffa0c036c5c> in <module>
# ----> 1 nlp = spacy.load('C:/Users/haghigy/AppData/Local/Continuum/anaconda3/lib/site-packages/spacy/en_core_web_sm-2.1.0')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\__init__.py in load(name, **overrides)
#      13 from .glossary import explain
#      14 from .about import __version__
# ---> 15 from .errors import Errors, Warnings, deprecation_warning
#      16 from . import util
#      17
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\util.py in load_model(name, **overrides)
#     117 def load_model(name, **overrides):
#     118     """Load a model from a shortcut link, package or data path.
# --> 119
#     120     name (unicode): Package name, shortcut link or model path.
# ...

# %%
nlp=spacy.load('en_core_web_sm')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-55-91e8057f17ae> in <module>
# ----> 1 nlp=spacy.load('en_core_web_sm')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\__init__.py in load(name, **overrides)
#      13 from .glossary import explain
#      14 from .about import __version__
# ---> 15 from .errors import Errors, Warnings, deprecation_warning
#      16 from . import util
#      17
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\util.py in load_model(name, **overrides)
#     117 def load_model(name, **overrides):
#     118     """Load a model from a shortcut link, package or data path.
# --> 119
#     120     name (unicode): Package name, shortcut link or model path.
#     121     **overrides: Specific overrides, like pipeline components to disable.
#
# ...

# %%
nlp = spacy.load('en')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-56-76abff010c5f> in <module>
# ----> 1 nlp = spacy.load('en')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\__init__.py in load(name, **overrides)
#      13 from .glossary import explain
#      14 from .about import __version__
# ---> 15 from .errors import Errors, Warnings, deprecation_warning
#      16 from . import util
#      17
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\spacy\util.py in load_model(name, **overrides)
#     117 def load_model(name, **overrides):
#     118     """Load a model from a shortcut link, package or data path.
# --> 119
#     120     name (unicode): Package name, shortcut link or model path.
#     121     **overrides: Specific overrides, like pipeline components to disable.
#
# ...

# %%
items.Item.dtypes
# Out:
# dtype('O')

# %%
library=pd.read_json("library")

# %%
library[29]['ingredients']
# Out:
# ['pork butt',
#  'Sriracha',
#  'ketchup',
#  'lime juice',
#  'dried parsley',
#  'honey',
#  'ground black pepper',
#  'salt',
#  'olive oil']

# %%
for recipe in library:
    for ingredient in library[recipe]['ingredients']:
        print(ingredient)
# Out:
# cherry tomatoes
# olive oil
# garlic
# salt
# pepper
# penne
# fresh mozzarella
# fresh basil
# tomatoes
# carrot
# white onion
# garlic cloves
# olive oil
# basil leaves
# Himalayan salt
# vegetable broth
# black pepper
# Tuscan kale
# extra virgin olive oil
# garlic
# grape tomatoes
# balsamic vinegar
# zucchini
# yellow squash
# tomatoes
# basil
# olive oil
# grated parmesan cheese
# sea salt
# black pepper
# whole wheat penne
# fire roasted tomatoes
# vegan cream cheese
# fresh basil leaves
# kosher salt
# spinach
# plum tomatoes
# extra virgin olive oil
# chopped fresh thyme
# garlic cloves
# tomatoes
# avocados
# red onion
# chopped cilantro
# limes
# extra-virgin olive oil
# salt
# sausage
# flour
# milk
# salt
# pepper
# tomatoes
# olive oil
# herbs de provence
# garlic powder
# heirloom tomatoes
# olive oil
# salt
# old bread
# herbes de provence
# lemon
# parmesan cheese
# cheese tortellini
# unsalted butter
# garlic
# all purpose flour
# heavy cream
# salt
# ...
